# %% [markdown]
# # Convolutional Neural Network

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Training_set/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Test_set/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 10)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 1388s 6s/step - loss: 0.6919 - accuracy: 0.5461 - val_loss: 0.7248 - val_accuracy: 0.5235
# Epoch 2/10
# 250/250 [==============================] - 81s 323ms/step - loss: 0.6426 - accuracy: 0.6361 - val_loss: 0.6219 - val_accuracy: 0.6595
# Epoch 3/10
# 250/250 [==============================] - 81s 323ms/step - loss: 0.5956 - accuracy: 0.6876 - val_loss: 0.5783 - val_accuracy: 0.6970
# Epoch 4/10
# 250/250 [==============================] - 80s 320ms/step - loss: 0.5471 - accuracy: 0.7216 - val_loss: 0.5498 - val_accuracy: 0.7195
# Epoch 5/10
# 250/250 [==============================] - 80s 318ms/step - loss: 0.5104 - accuracy: 0.7455 - val_loss: 0.5522 - val_accuracy: 0.7235
# Epoch 6/10
# 250/250 [==============================] - 78s 313ms/step - loss: 0.4936 - accuracy: 0.7565 - val_loss: 0.4861 - val_accuracy: 0.7740
# Epoch 7/10
# 250/250 [==============================] - 77s 307ms/step - loss: 0.4692 - accuracy: 0.7696 - val_loss: 0.4813 - val_accuracy: 0.7660
# Epoch 8/10
# 250/250 [==============================] - 76s 304ms/step - loss: 0.4588 - accuracy: 0.7803 - val_loss: 0.4723 - val_accuracy: 0.7690
# Epoch 9/10
# 250/250 [==============================] - 76s 304ms/step - loss: 0.4384 - accuracy: 0.7984 - val_loss: 0.4672 - val_accuracy: 0.7860
# Epoch 10/10
# 250/250 [==============================] - 76s 305ms/step - loss: 0.4233 - accuracy: 0.7977 - val_loss: 0.4955 - val_accuracy: 0.7650

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Single prediction /single_prediction/cat_or_dog_2.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

# %%
print(prediction)
# Out:
# dog
