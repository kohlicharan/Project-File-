# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset_train = pd.read_csv("Google_Stock_Price_Train.csv")

# %%
training_set = dataset_train.iloc[:, 1:2].values

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
#60 times steps- at each time t and look at 60 previous time steps, then make new prediction 
# 1 time step leads to overfitting, 20 is still too low
#60 previous financial days- in 3 months 
X_train = []
y_train = []
for i in range(60, 1258): # upper bound is number of values 
  X_train.append(training_set_scaled[i-60:i, 0]) #takes 60 previous stock prices from 60 past stock prices
  y_train.append(training_set_scaled[i, 0]) #contains stock price learned to predict 
X_train, y_train = np.array(X_train), np.array(y_train) # make into numpy arrays 
#Need to add dimension to because not only prescition with one stock price but other indicators (like other columns in dataset  or other stocks that may affect this one )

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True)) 

regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs = 200, batch_size = 32) # CHANGE BACK TO 100 IF NOT WORK
# Out:
# Epoch 1/200
# 38/38 [==============================] - 5s 46ms/step - loss: 0.0442
# Epoch 2/200
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0066
# Epoch 3/200
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0056
# Epoch 4/200
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0053
# Epoch 5/200
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0053
# Epoch 6/200
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0059
# Epoch 7/200
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0047
# Epoch 8/200
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0049
# Epoch 9/200
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0048
# Epoch 10/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0046
# Epoch 11/200
# 38/38 [==============================] - 2s 49ms/step - loss: 0.0045
# Epoch 12/200
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0042
# Epoch 13/200
# 38/38 [==============================] - 2s 46ms/step - loss: 0.0038
# Epoch 14/200
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0038
# Epoch 15/200
# 38/38 [==============================] - 2s 44ms/step - loss: 0.0039
# Epoch 16/200
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0038
# Epoch 17/200
# 38/38 [==============================] - 2s 45ms/step - loss: 0.0049
# Epoch 18/200
# 38/38 [==============================] - 2s 47ms/step - loss: 0.0041
# Epoch 19/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0040
# Epoch 20/200
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0041
# Epoch 21/200
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0036
# Epoch 22/200
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0034
# Epoch 23/200
# 38/38 [==============================] - 2s 53ms/step - loss: 0.0032
# Epoch 24/200
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0035
# Epoch 25/200
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0031
# Epoch 26/200
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0034
# Epoch 27/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0032
# Epoch 28/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0033
# Epoch 29/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0039
# Epoch 30/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0039
# Epoch 31/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.
200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 158/200
# 38/38 [==============================] - 2s 50ms/step - loss: 9.9434e-04
# Epoch 159/200
# 38/38 [==============================] - 2s 53ms/step - loss: 9.9002e-04
# Epoch 160/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 161/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 162/200
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0011
# Epoch 163/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0011
# Epoch 164/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.7375e-04
# Epoch 165/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 166/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 167/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 168/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0012
# Epoch 169/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 170/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.7497e-04
# Epoch 171/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 172/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0010
# Epoch 173/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 174/200
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0014
# Epoch 175/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 176/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 177/200
# 38/38 [==============================] - 2s 50ms/step - loss: 0.0010
# Epoch 178/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.8676e-04
# Epoch 179/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 180/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 181/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 182/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 183/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 184/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0011
# Epoch 185/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 186/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 187/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.3523e-04
# Epoch 188/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 189/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.7499e-04
# Epoch 190/200
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0010
# Epoch 191/200
# 38/38 [==============================] - 2s 58ms/step - loss: 9.5751e-04
# Epoch 192/200
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0010
# Epoch 193/200
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0010
# Epoch 194/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.9841e-04
# Epoch 195/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.1400e-04
# Epoch 196/200
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0012
# Epoch 197/200
# 38/38 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 198/200
# 38/38 [==============================] - 2s 52ms/step - loss: 9.5788e-04
# Epoch 199/200
# 38/38 [==============================] - 2s 51ms/step - loss: 9.5907e-04
# Epoch 200/200
# 38/38 [==============================] - 2s 50ms/step - loss: 9.7112e-04

# %%
dataset_test = pd.read_csv("Google_Stock_Price_Test.csv")
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values #getting input of each previous financial days
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 227):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# <ipython-input-17-2834c4a14d8b>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   X_test = np.array(X_test)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-2834c4a14d8b> in <module>
#       7     X_test.append(inputs[i-60:i, 0])
#       8 X_test = np.array(X_test)
# ----> 9 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#      10 predicted_stock_price = regressor.predict(X_test)
#      11 predicted_stock_price = sc.inverse_transform(predicted_stock_price)
#
# IndexError: tuple index out of range

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot( color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
